# %% [markdown]
# <a href="https://colab.research.google.com/github/342olive/scraped-data/blob/main/NLP-Applications/03_fasttext_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#page 247: fasttext.py

# %% [markdown]
# Running a model using FastText emneddings:

# %%
import io
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from sklearn import linear_model
from sklearn import metrics
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer

def load_vectors(fname):
fin = io.open(
fname,
'r',
encoding='utf-8',
newline='\n',
errors='ignore'
)

line= fin.readline() #fin is a file object, it cant be used with split method. line however stores string
parts= line.split() # if we expect messy text, we will use default split behaviour to treat multiple spaces as one
n,d= map(int,parts)

data={}
for line in fin:
  remove_trails= line.rstrip()
  tokens= remove_trails.split(' ') #split creates a list of strings, cuts the string wherever seperator appears
  data[tokens[0]]= list(map(float,tokens[1:]))
return data

def sentence_to_vec(s, embedding_dict, stop_words, tokenizer):
.
.
.
